# %% [markdown]
# # SNN Model Implementations: Spiking Resnet
#
# 1. Load CIFAR10 data
# 2. [Model](https://github.com/VicenteAlex/Spiking_ResNet/tree/main)
#
# ---
#
# - ISSUE: CUDA required, but not used for Apple devices

# %%
import os
import sys
# Get the current working directory of the notebook
notebook_dir = os.getcwd()

# Add the parent directory to the system path
sys.path.append(os.path.join(notebook_dir, '../'))

import data_loader

from spiking_resnet import SpikingResNet

# %%
data_loader.build_cifar_ten_pytorch(show_data=True)
# Out:
# horse plane car   bird

# %% [markdown]
# ## Set up for GColab to use CUDA

# %%
spiking_resnet_class = SpikingResNet()
spiking_resnet_class
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 spiking_resnet_class = SpikingResNet()
#       2 spiking_resnet_class
#
# TypeError: SNNModel.__init__() missing 2 required positional arguments: 'model_name' and 'model_path'
